# %% [markdown]
# # Final Project Submission
#
# Please fill out:
# * Student name: Wambui Mutero
# * Student pace: Part time
# * Scheduled project review date/time: Tuesday 30th January 2023 - Sunday 5th February 2023
# * Instructor name: Samwel Jane
# * Blog post URL:

# %% [markdown]
# ## Movie Data Analysis - remember to use markdown cells for comments as well!
# This is my first project based on the analysis of Movie data using Exploratory Data Analysis to generate insights for a business stakeholder - Microsoft movie studio.
# I am performing an extensive Exploratory Data Analysis on Movies Metadata collected from Box Office Mojo and IMDB movie datasets.
# I was able to visualize features that influence the output (genre and gross income), the popular genres as well as ratings on IMDB.

# %%
import pandas as pd
import numpy as np
import csv

# %%
# Checking the path in order to put in dataset.
pwd
# Out:
# 'C:\\Users\\ke-guest\\Movie-Analysis'

# %%
# The first dataset we will interpret - Box Office Mojo data
pd.read_csv('C:/Users/ke-guest/Downloads/Movie-Analysis/bom.movie_gross.csv.gz')
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
moviegross = pd.read_csv('C:/Users/ke-guest/Downloads/Movie-Analysis/bom.movie_gross.csv.gz')

# %%
moviegross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
columns = list(moviegross.columns)
columns
# Out:
# ['title', 'studio', 'domestic_gross', 'foreign_gross', 'year']

# %%
moviegross.tail(10)
# Out:
#                              title      studio  domestic_gross foreign_gross  \
# 3377               Let Yourself Go        Men.         12200.0           NaN
# 3378                 Hannah (2018)         PDF         11700.0           NaN
# 3379                      Souvenir      Strand         11400.0           NaN
# 3380  Furious (Legend of Kolovrat)     CARUSEL         10000.0           NaN
# 3381           Beauty and the Dogs       Osci.          8900.0           NaN
# 3382                     The Quake       Magn.          6200.0           NaN
# 3383   Edward II (2018 re-release)          FM          4800.0           NaN
# 3384                      El Pacto        Sony          2500.0           NaN
# 3385                      The Swan  Synergetic          2400.0           NaN
# 3386             An Actor Prepares       Grav.          1700.0           NaN
#
#       year
# 3377  2018
# 3378  2018
# 3379  2018
# 3380  2018
# 3381  2018
# 3382  2018
# 3383  2018
# 3384  2018
# ...

# %%
# There are some columns with missing values. 
# This could cause a lot of problems for analysis and plotting if not addressed and resolved early in the process.
#   check which columns have missing values and how much missing data they have.
print("Missing values distribution: ")
print(moviegross.isnull().mean())
print("")
# Out:
# Missing values distribution:
# title             0.000000
# studio            0.001476
# domestic_gross    0.008267
# foreign_gross     0.398583
# year              0.000000
# dtype: float64

# %%
# these are insights you can gather:

# foreign_gross column has the highest percentage of missing data ~ 39%
# studio, domestic_gross don’t have that much missing data ~ 0.1% - 0.8%
# Fortunately, the other two columns-title and year other are not empty.

# %%
# Check the data type of each column
print("Column datatypes: ")
print(moviegross.dtypes)
# Out:
# Column datatypes:
# title              object
# studio             object
# domestic_gross    float64
# foreign_gross      object
# year                int64
# dtype: object

# %%
# check for trailing whitespaces
# getting all the columns with string/mixed type values
str_cols = list(moviegross.columns)
str_cols.remove('year',)

# %%
df = moviegross
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
moviegross = df
moviegross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
# names of the columns
columns = ['title', 'studio', 'domestic_gross', 'foreign_gross', 'year']

# looping through the columns to fill the entries with NaN values with ""
for column in columns:
    moviegross[column] = moviegross[column].fillna("")

# %%
# gathering information about the dataset.
moviegross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3387 non-null   object
#  2   domestic_gross  3387 non-null   object
#  3   foreign_gross   3387 non-null   object
#  4   year            3387 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 132.4+ KB

# %%
print(moviegross.isnull().sum())
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Set plot space as inline for inline plots and qt for external plots
# %matplotlib inline

# %%
# Plotting a bar graph of the years against the domestic gross- which is denoted by 1e10 meaning the values are 10^10
import pandas as pd
import matplotlib.pyplot as plt

# loading the CSV data 
data = pd.read_csv('C:/Users/ke-guest/Downloads/Movie-Analysis/bom.movie_gross.csv.gz')
data = data.groupby(['year'])['domestic_gross'].sum().sort_values(ascending=False)

plt.bar(data.index, data.values)
plt.xlabel('Year')
plt.ylabel('Domestic Gross')
plt.xticks(rotation=90)
plt.title('Total Domestic Gross by Year')
plt.show()

# %%
# Plotting a scatter graph of the years against the domestic gross- which is denoted by 1e8 meaning the values are 10^8
import pandas as pd
import seaborn as sns

data = pd.read_csv('C:/Users/ke-guest/Downloads/Movie-Analysis/bom.movie_gross.csv.gz')

sns.scatterplot(x='year', y='domestic_gross', data=data)
sns.set_style("whitegrid")
sns.set(font_scale=1.5)
sns.despine()

plt.xlabel('Year')
plt.ylabel('Domestic Gross')
plt.title('Scatter Plot of Year vs Domestic Gross')
plt.show()

# %%
# Both the bar graph and scatter plot graph showcase that the domestic gross of the different movies and films 
#  increased in Box Office Mojo as the years progressed. The films were getting more and more recognized and
# hence many people were interacting with them more over the years.

# %%
import pandas as pd
import numpy as np
import csv

# %%
# The second dataset we will interpret - Box Office Mojo data
pd.read_csv('C:/Users/ke-guest/Downloads/Movie-Analysis/imdb.title.ratings.csv.gz')
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
# Assigning a variable to the dataset.
imdbratings = pd.read_csv('C:/Users/ke-guest/Downloads/Movie-Analysis/imdb.title.ratings.csv.gz')

# %%
imdbratings.head(7)
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
# 5   tt1069246            6.2       326
# 6   tt1094666            7.0      1613

# %%
# identifying access to the different columns of the dataset,
columns = list(imdbratings.columns)
columns
# Out:
# ['tconst', 'averagerating', 'numvotes']

# %%
# examining missing values
print("Missing values distribution: ")
print(imdbratings.isnull().mean())
print("")
# Out:
# Missing values distribution:
# tconst           0.0
# averagerating    0.0
# numvotes         0.0
# dtype: float64

# %%
# Our dataset imdbratings does not have missing values. We don't have to handle any missing values in this dataset.

# %%
# check datatype in each column
print("Column datatypes: ")
print(imdbratings.dtypes)
# Out:
# Column datatypes:
# tconst            object
# averagerating    float64
# numvotes           int64
# dtype: object

# %%
# Import Seaborn and Pandas 
import pandas as pd
import seaborn as sns

data = pd.read_csv('C:/Users/ke-guest/Downloads/Movie-Analysis/imdb.title.ratings.csv.gz')

# function from the Seaborn library is then used to create a histogram of the 'averagerating' column.
# The kde argument is set to False to remove the density plot.
sns.distplot(data['averagerating'], kde=False)
sns.set_style("whitegrid")
sns.set(font_scale=1.5)
sns.despine()

plt.xlabel('IMDB Rating')
plt.ylabel('Frequency')
plt.title('Histogram of IMDB Ratings')
plt.show()
# Out:
# C:\Users\ke-guest\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# The above histogram indicates that the highest ratings on IMDB are more prevalent in the 7 point mark, which is ideally above average.
# The frequency in the above example refers to the number of occurrences of a particular IMDB rating value in the averagerating column of the data.

# Insights - In other words, the frequency of each IMDB rating value tells us how many movies in the data have received that particular rating. For example, if the frequency of the rating 7.0 is around 4500, it means that there are 4500 or more movies in the data that have received a rating of 7.0.

# %%
# Import the different analysis toolkits.
import pandas as pd
import numpy as np
import csv

# %%
# The third dataset we will interpret - IMDB basics
pd.read_csv('C:/Users/ke-guest/Downloads/Movie-Analysis/imdb.title.basics.csv.gz')
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
# Assign a variable - imdbtitle to our dataset
imdbtitle = pd.read_csv('C:/Users/ke-guest/Downloads/Movie-Analysis/imdb.title.basics.csv.gz')

# %%
imdbtitle.head(7)
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
# 5  tt0111414                      A Thin Life                 A Thin Life
# 6  tt0112502                          Bigfoot                     Bigfoot
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
# 5        2018             75.0                Comedy
# ...

# %%
imdbtitle.tail()
# Out:
#            tconst                                primary_title  \
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes       genres
# 146139            123.0        Drama
# 146140              NaN  Documentary
# 146141              NaN       Comedy
# 146142            116.0          NaN
# ...

# %%
# There are some columns with missing values that have been observed from the data above of the first 7 and last 5 values. 
# This could cause a lot of problems for analysis and plotting if not addressed and resolved early in the process.
# Check which columns have missing values and how much missing data they have.
print("Missing values distribution: ")
print(imdbtitle.isnull().mean())
print("")
# Out:
# Missing values distribution:
# tconst             0.000000
# primary_title      0.000000
# original_title     0.000144
# start_year         0.000000
# runtime_minutes    0.217176
# genres             0.037005
# dtype: float64

# %%
# these are insights you can gather:

# the runtime_minutes column has the highest percentage of missing data ~ 21%
# genres and original_title don’t have that much missing data ~ 3% and 0.01%
# Fortunately, the other three columns -tconst, primary_title and start_year have all their values present

# %%
# Checking the aggregation functions of the dataset
imdbtitle.describe()
# Out:
#           start_year  runtime_minutes
# count  146144.000000    114405.000000
# mean     2014.621798        86.187247
# std         2.733583       166.360590
# min      2010.000000         1.000000
# 25%      2012.000000        70.000000
# 50%      2015.000000        87.000000
# 75%      2017.000000        99.000000
# max      2115.000000     51420.000000

# %%
# check datatype in each column
print("Column datatypes: ")
print(imdbtitle.dtypes)
# Out:
# Column datatypes:
# tconst              object
# primary_title       object
# original_title      object
# start_year           int64
# runtime_minutes    float64
# genres              object
# dtype: object

# %%
# all the columns have object as their datatype aside from start_year- that has intergers and runtime_minutes - float.

# %%
# The columns with missing values are not very prevalent and hence we do not drop them but fill them using the .fillna() method.

# %%
# names of the columns
columns = ['original_title','runtime_minutes','genres']

# looping through the columns to fill the entries with NaN values with "" as it is the most approriate for filling in the missing values.
for column in columns:
    imdbtitle[column] = imdbtitle[column].fillna("")

# %%
# Recheck if there's any missing values in the dataset
print("Missing values distribution: ")
print(imdbtitle.isnull().mean())
print("")
# Out:
# Missing values distribution:
# tconst             0.0
# primary_title      0.0
# original_title     0.0
# start_year         0.0
# runtime_minutes    0.0
# genres             0.0
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('C:/Users/ke-guest/Downloads/Movie-Analysis/imdb.title.basics.csv.gz')


# Calculate the average runtime for each year
avg_runtime = df.groupby('start_year').mean()['runtime_minutes']

# Plot a line plot of the average runtime over the years
plt.plot(avg_runtime.index, avg_runtime.values)

# Add labels and title to the plot
plt.xlabel('Start Year')
plt.ylabel('Average Runtime (Minutes)')
plt.title('Average Runtime of Movies over the Years')

# Show the plot
plt.show()

# %% [raw]
# # The above diagram shows a line graph showing the average runtime of movies in the IMDB dataset over the years.
# # In 2010 it starts steadily and spikes up until 2012 and then theres a sudden plummet and then it plateaus for a bit,
# # It then shoots up recording the highest all time average runtime in 2022.

# %% [raw]
# # A conclusion of analysing the data to help Microsoft break into the movie and film industry has shown us some great insights.
#
# # For the first data set used we found out that:  increased in Box Office Mojo as the years progressed. The films were getting more and more recognized and
# # hence many people were interacting with them more over the years. This can seemingly explain: - At the beginning the interaction with the movie studio is slow,
# # but as people get to know and experience Box Mojo user interaction increased as well. - The total gross income increases steadily and is highest in the year 2018.
# # A business recommendation based on the insights obtained: The business will start slowly as it steadily grows both in monetary value as well as being consumed.
#
# # For the second data set we obtained, we were getting the IMDB ratings of the different films. Most of the films are at the 7.0 point mark which is above average.
# # This indicates that the movies being rated by IMDB are considered good. This is shown by the frequency of the number of votes casted to the consumers.
#
# # For the final dataset it showcases the average runtime calculated against the years. AS the years progressed there was an increase in runtime,
# # This can be due to a couple of factors: Increased move knowledge and production competency over the years to produce longer movies with more screentime to wow the consumer.
# # -Understanding how the momentum it takes for a movie to have a perfect based storyline.
# # -Having the best people in the movie industry directing and producing the movies.
# # Microsoft can identify great people in the industry who they can bring into the team and who can help transform and give an experienced perspective of the movie industry which will then put them at a better and gaining position.
